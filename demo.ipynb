# %%
import os
os.chdir('/home/haikim20/stat495/stat495-content/project/src')

# %%
# %run main.py -h
# Out:
# usage: main.py [-h] [--tune_param] [--cv_fold CV_FOLD] [--seed SEED]
#                [--param_ver PARAM_VER] [--pretrained] [--forecast_mode]
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --tune_param          Tune hyperparameters
#   --cv_fold CV_FOLD     Specify number of folds for CV
#   --seed SEED
#   --param_ver PARAM_VER
#                         Specify the version of tuned hyperparameters saved as
#                         JSON
#   --pretrained          Use a pretrained model
#   --forecast_mode       Use price forecasting for portfolio optimization (if
#                         False, same as Modern Portfolio Theory)

# %%
# %run main.py --param_ver 20231212 --forecast_mode
# Out:
# AMZN started
# model training started
# /home/haikim20/.local/lib/python3.9/site-packages/xgboost/core.py:160: UserWarning: [01:53:07] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# forecast started
# UNH started
# model training started
# /home/haikim20/.local/lib/python3.9/site-packages/xgboost/core.py:160: UserWarning: [01:53:16] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# forecast started
# BRK-B started
# model training started
# /home/haikim20/.local/lib/python3.9/site-packages/xgboost/core.py:160: UserWarning: [01:53:33] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# forecast started
# JPM started
# model training started
# ...
